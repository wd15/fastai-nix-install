# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %%
from fastai.vision import *

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# # Download the Data

# %%
classes = ["arrowhead", "anthurium", "aloe"]

path = Path('data/plants')

for klass in classes:
    dest = path/klass
    dest.mkdir(parents=True, exist_ok=True)
    download_images(klass + '.csv', dest, max_pics=500)
    verify_images(dest, delete=True, max_size=500)
    
#for klas in classes:
#    print(c)
#    verify_images(path/c, delete=True, max_size=500)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='500' class='' max='500', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [500/500 01:27<00:00]
#     </div>
# Error http://ypfservi.club/wp-content/uploads/2018/03/a-vine-plant-get-to-know-the-chocolate-vine-arrowhead-vine-indoor-plant.jpg HTTPConnectionPool(host='ypfservi.club', port=80): Max retries exceeded with url: /wp-content/uploads/2018/03/a-vine-plant-get-to-know-the-chocolate-vine-arrowhead-vine-indoor-plant.jpg (Caused by ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
# Error http://naplanete.club/wp-content/uploads/2017/11/arrowhead-plant-pictures-black-arrowhead-vine-arrowhead-plant-garden-santa-fe-cinepolis.jpg HTTPConnectionPool(host='naplanete.club', port=80): Max retries exceeded with url: /wp-content/uploads/2017/11/arrowhead-plant-pictures-black-arrowhead-vine-arrowhead-plant-garden-santa-fe-cinepolis.jpg (Caused by ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
# Error http://naplanete.club/wp-content/uploads/2017/11/arrowhead-plant-pictures-arrowhead-vine-arrowhead-vine-garden-santa-fe-directorio.jpg HTTPConnectionPool(host='naplanete.club', port=80): Max retries exceeded with url: /wp-content/uploads/2017/11/arrowhead-plant-pictures-arrowhead-vine-arrowhead-vine-garden-santa-fe-directorio.jpg (Caused by ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
# Error http://www.nitasgarden.com/wp-content/uploads/2019/01/076-600x600.jpg HTTPConnectionPool(host='www.nitasgarden.com', port=80): Max retries exceeded with url: /wp-content/uploads/2019/01/076-600x600.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fe80aa68b38>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
# Error http://coolman.club/wp-content/uploads/2017/10/arrowhead-plant-pruning-butterfly-plant-arrowhead-plant-garden-city-ks.jpg HTTPConnectionPool(host='coolman.club', port=80): Max retries exceeded with url: /wp-content/uploads/2017/10/arrowhead-plant-pruning-butterfly-plant-arrowhead-plant-garden-city-ks.jpg (Caused by ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
# Error http://ypfservi.club/wp-content/uploads/2018/03/a-vine-plant-get-to-know-the-chocolate-vine-arrowhead-vine-indoor-plant.jpg HTTPConnectionPool(host='ypfservi.club', port=80): Max retries exceeded with url: /wp-content/uploads/2018/03/a-vine-plant-get-to-know-the-chocolate-vine-arrowhead-vine-indoor-plant.jpg (Caused by ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
# Error http://bestespressomachines.club/wp-content/uploads/2017/09/viney-plant-arrowhead-vine-indoor-plant.jpg HTTPConnectionPool(host='bestespressomachines.club', port=80): Max retries exceeded with url: /wp-content/uploads/2017/09/viney-plant-arrowhead-vine-indoor-plant.jpg (Caused by ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
# Error https://www.txstate.edu/cache900179355b8df95e4cf74c7fce7ccdd0/imagehandler/scaler/gato-docs.its.txstate.edu/jcr:c4e54b55-979b-4890-9c0d-1c5013b4b542/arrowhead%2Bvine.jpg?mode=fit&width=1620 HTTPSConnectionPool(host='www.txstate.edu', port=443): Read timed out. (read timeout=4)
# Error http://vesnajob.info/wp-content/uploads/2018/04/low-light-vines-low-light-indoor-plants-you-can-decorate-with-arrowhead-vine.jpg HTTPConnectionPool(host='vesnajob.info', port=80): Max retries exceeded with url: /wp-content/uploads/2018/04/low-light-vines-low-light-indoor-plants-you-can-decorate-with-arrowhead-vine.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fe80b2fb048>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error http://palmview-oelgarden.weebly.com/uploads/4/0/0/9/40094981/5123681_orig.jpg HTTPConnectionPool(host='palmview-oelgarden.weebly.com', port=80): Max retries exceeded with url: /uploads/4/0/0/9/40094981/5123681_orig.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7fe80b325e48>, 'Connection to palmview-oelgarden.weebly.com timed out. (connect timeout=4)'))
# Error http://vesnajob.info/wp-content/uploads/2018/04/low-light-vines-low-light-hanging-plants-low-light-hanging-plants-indoor-low-light.jpg HTTPConnectionPool(host='vesnajob.info', port=80): Max retries exceeded with url: /wp-content/uploads/2018/04/low-light-vines-low-light-hanging-plants-low-light-hanging-plants-indoor-low-light.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fe80b324518>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error http
# $ cd /home/paperspace/.fastai/data
# $ wget -c http://tcinterplants.com/userfiles/image/12270253_1647926135494767_798428983_n.jpg
# $ tar -zxvf 12270253_1647926135494767_798428983_n.jpg
#
# And re-run your code once the download is successful
#
# Error https://www.coolgarden.me/wp-content/uploads/2013/06/anthurium1.jpg HTTPSConnectionPool(host='www.coolgarden.me', port=443): Max retries exceeded with url: /wp-content/uploads/2013/06/anthurium1.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe80b37fef0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error http://rockethomes.in/media/catalog/product/w/h/white_beauty_17cm.jpg HTTPConnectionPool(host='rockethomes.in', port=80): Max retries exceeded with url: /media/catalog/product/w/h/white_beauty_17cm.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fe80a301668>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='485' class='' max='485', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [485/485 00:04<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='data/plants/anthurium/00000440.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/anthurium/00000188.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/anthurium/00000145.jpg'>
# Image data/plants/anthurium/00000274.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/plants/anthurium/00000090.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/anthurium/00000123.jpg'>
# Image data/plants/anthurium/00000387.jpg has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/plants/anthurium/00000285.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/anthurium/00000250.jpg'>
# Image data/plants/anthurium/00000166.jpg has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/plants/anthurium/00000230.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/anthurium/00000339.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/anthurium/00000268.jpg'>
# Image data/plants/anthurium/00000110.png has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/plants/anthurium/00000324.jpg'>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='500' class='' max='500', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [500/500 00:20<00:00]
#     </div>
# Error x-raw-image:///de80a11c8a7d86a0c37807f8f4512087de79b90fb5c43749b46c4c4c9f09a744 No connection adapters were found for 'x-raw-image:///de80a11c8a7d86a0c37807f8f4512087de79b90fb5c43749b46c4c4c9f09a744'
# Error https://www.plunketts.com.au/product_images/uploaded_images/aloe-pack-2018.png HTTPSConnectionPool(host='www.plunketts.com.au', port=443): Max retries exceeded with url: /product_images/uploaded_images/aloe-pack-2018.png (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')])")))
# Error https://www.dokterdokter.nl/upload/images/dossier/aloe-vera-dossier.jpg HTTPSConnectionPool(host='www.dokterdokter.nl', port=443): Max retries exceeded with url: /upload/images/dossier/aloe-vera-dossier.jpg (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe80a298d30>, 'Connection to www.dokterdokter.nl timed out. (connect timeout=4)'))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='493' class='' max='493', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [493/493 00:03<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000390.jpg'>
# Image data/plants/aloe/00000229.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000345.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000239.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000286.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000432.svg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000028.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000303.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000344.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000274.jpg'>
# Image data/plants/aloe/00000063.png has 4 instead of 3 channels
# Image data/plants/aloe/00000244.png has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000378.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000230.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000317.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000263.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000175.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000439.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000414.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000078.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000438.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000223.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000397.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000364.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000419.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000420.jpg'>
# Image data/plants/aloe/00000278.jpg has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000352.jpg'>
# cannot identify image file <_io.BufferedReader name='data/plants/aloe/00000258.jpg'>

# %% [markdown]
# # View the data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['aloe', 'anthurium', 'arrowhead']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['aloe', 'anthurium', 'arrowhead'], 3, 1116, 279)

# %% [markdown]
# # Train Model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:29 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.861145</th>
#     <th>0.339174</th>
#     <th>0.143369</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.558065</th>
#     <th>0.290255</th>
#     <th>0.089606</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.408774</th>
#     <th>0.280871</th>
#     <th>0.100358</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.334690</th>
#     <th>0.273276</th>
#     <th>0.103943</th>
#   </tr>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-4,3e-3))
# Out:
# Total time: 00:16 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.299319</th>
#     <th>0.537017</th>
#     <th>0.125448</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.222449</th>
#     <th>0.279096</th>
#     <th>0.089606</th>
#   </tr>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# # Interpret

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# # Cleanup

# %%
from fastai.widgets import *

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
ImageCleaner(ds, idxs, path)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
ds, idxs = DatasetFormatter().from_similars(learn, ds_type=DatasetType.Valid)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='18' class='' max='18', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [18/18 00:04<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'black'/'00000021.jpg')
img
# Out:
# Image (3, 332, 500)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, jsut make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category black

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# Total time: 00:03 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>8.451075</th>
#     <th>25967602.000000</th>
#     <th>0.386667</th>
#   </tr>
# </table>

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# Total time: 00:16 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.570959</th>
#     <th>1.710382</th>
#     <th>0.786667</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.601813</th>
#     <th>1.513131</th>
#     <th>0.813333</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.572220</th>
#     <th>1.419366</th>
#     <th>0.853333</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.546088</th>
#     <th>1.365022</th>
#     <th>0.866667</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>1.526772</th>
#     <th>1.331935</th>
#     <th>0.800000</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:03 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.439045</th>
#     <th>13.927007</th>
#     <th>0.866667</th>
#   </tr>
# </table>

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 00:37<00:37]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.102108</th>
#     <th>1.184045</th>
#     <th>0.718475</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='11', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-3d10cbf98e25> in <module>
# ----> 1 learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, wd, callbacks, **kwargs)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor,
#      21                                         pct_start=pct_start, **kwargs))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, **kwargs:Any):
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     176         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     177         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 178             callbacks=self.callbacks+callbacks)
#     179
#     180     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/utils/mem.py in wrapper(*args, **kwargs)
#      83
#      84         try:
# ---> 85             return func(*args, **kwargs)
#      86         except Exception as e:
#      87             if "CUDA out of memory" in str(e) or tb_clear_frames=="1":
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      93             if not data.empty_val:
#      94                 val_loss = validate(model, data.valid_dl, loss_func=loss_func,
# ---> 95                                        cb_handler=cb_handler, pbar=pbar)
#      96             else: val_loss=None
#      97             if cb_handler.on_epoch_end(val_loss): break
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in validate(model, dl, loss_func, cb_handler, pbar, average, n_batch)
#      52         for xb,yb in progress_bar(dl, parent=pbar, leave=(pbar is not None)):
#      53             if cb_handler: xb, yb = cb_handler.on_batch_begin(xb, yb, train=False)
# ---> 54             val_losses.append(loss_batch(model, xb, yb, loss_func, cb_handler=cb_handler))
#      55             if not is_listy(yb): yb = [yb]
#      56             nums.append(yb[0].shape[0])
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      18     if not is_listy(xb): xb = [xb]
#      19     if not is_listy(yb): yb = [yb]
# ---> 20     out = model(*xb)
#      21     out = cb_handler.on_loss_begin(out)
#      22
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/torchvision/models/resnet.py in forward(self, x)
#      74         residual = x
#      75
# ---> 76         out = self.conv1(x)
#      77         out = self.bn1(out)
#      78         out = self.relu(out)
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# KeyboardInterrupt:
